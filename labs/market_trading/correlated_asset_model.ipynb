# %% [markdown]
# # Market Asset Feature Engineering

# %% [markdown]
# ## Installs

# %% [markdown]
# ## Imports

# %%
# %run ./../../../utilities/model_frameworks/bifrost_gradient_booster.ipynb
# Out:
# Requirement already satisfied: xgboost in /Users/deanmartin/miniforge3/envs/pytorch/lib/python3.9/site-packages (1.6.1)
# Requirement already satisfied: pandas in /Users/deanmartin/miniforge3/envs/pytorch/lib/python3.9/site-packages (1.4.3)
# Requirement already satisfied: numpy in /Users/deanmartin/miniforge3/envs/pytorch/lib/python3.9/site-packages (1.23.1)
# Requirement already satisfied: sklearn in /Users/deanmartin/miniforge3/envs/pytorch/lib/python3.9/site-packages (0.0)
# Requirement already satisfied: graphviz in /Users/deanmartin/miniforge3/envs/pytorch/lib/python3.9/site-packages (0.20.1)
# Requirement already satisfied: scipy in /Users/deanmartin/miniforge3/envs/pytorch/lib/python3.9/site-packages (from xgboost) (1.8.1)
# Requirement already satisfied: pytz>=2020.1 in /Users/deanmartin/miniforge3/envs/pytorch/lib/python3.9/site-packages (from pandas) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/deanmartin/miniforge3/envs/pytorch/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: scikit-learn in /Users/deanmartin/miniforge3/envs/pytorch/lib/python3.9/site-packages (from sklearn) (1.1.1)
# Requirement already satisfied: six>=1.5 in /Users/deanmartin/miniforge3/envs/pytorch/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/deanmartin/miniforge3/envs/pytorch/lib/python3.9/site-packages (from scikit-learn->sklearn) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in /Users/deanmartin/miniforge3/envs/pytorch/lib/python3.9/site-packages (from scikit-learn->sklearn) (1.1.0)

# %%
import glob
import pandas as pd
from datetime import datetime
from functools import reduce
import numpy as np

# %% [markdown]
# ## Utils

# %%
def rsi(prices, n=14):
    deltas = np.diff(prices)
    seed = deltas[:n+1]
    up = seed[seed>=0].sum()/n
    down = -seed[seed<0].sum()/n
    rs = up/down
    rsi = np.zeros_like(prices)
    rsi[:n] = 100. - 100./(1.+rs)

    for i in range(n, len(prices)):
        delta = deltas[i-1] # cause the diff is 1 shorter

        if delta>0:
            upval = delta
            downval = 0.
        else:
            upval = 0.
            downval = -delta

        up = (up*(n-1) + upval)/n
        down = (down*(n-1) + downval)/n

        rs = up/down
        rsi[i] = 100. - 100./(1.+rs)

    return rsi

# %% [markdown]
# ## Load Market Data From Files

# %%
interval: str = '1h'
data_path: str = '/Users/deanmartin/Source/fa.services.plutus/user_data/data/binance'
data_files: list = glob.glob(f'{data_path}/*-{interval}.json')
dataframes: list = list()
pair_names: list = list()

for file_path in data_files:
    try:
        pair_name: str = file_path.replace('\\','/').split('/')[-1].split(f'-{interval}')[0]
        dataframe: pd.DataFrame = pd.read_json(file_path)
        dataframe.columns = [ 'time', 'open', 'high', 'low', 'close', 'volume' ]
        dataframe['time'] = pd.to_datetime(dataframe['time'], unit='ms')
        dataframe.set_index('time', inplace=True)
        dataframe['close_next'] = dataframe['close'].shift(-1)
        
        # Indicators
        # Moving Average
        dataframe['MA_7MA'] = dataframe['close'].rolling(window=7).mean()
        dataframe['MA_7MA_std'] = dataframe['close'].rolling(window=7).std()
        dataframe['MA_15MA'] = dataframe['close'].rolling(window=15).mean()
        dataframe['MA_30MA'] = dataframe['close'].rolling(window=30).mean()
        dataframe['MA_60MA'] = dataframe['close'].rolling(window=60).mean()
        
        # MACD
        ewma = pd.Series.ewm
        close_26EMA = ewma(dataframe['close'], span=26).mean()
        close_12EMA = ewma(dataframe['close'], span=12).mean()
        dataframe['MACD'] = close_12EMA - close_26EMA
        
        # Bollinger bands.
        no_of_std = 2
        dataframe['MA_7MA_BB_high'] = dataframe['MA_7MA'] + no_of_std * dataframe['MA_7MA_std']
        dataframe['MA_7MA_BB_low'] = dataframe['MA_7MA'] - no_of_std * dataframe['MA_7MA_std']
        
        # RSI
        rsi_6 = rsi(dataframe['close'].values, 6)
        rsi_14 = rsi(dataframe['close'].values, 14)
        rsi_20 = rsi(dataframe['close'].values, 20)
        
        dataframe.columns = [f'{pair_name.lower()}__{c.lower()}' for c in dataframe.columns]

        pair_names.append(pair_name.lower())
        dataframes.append(dataframe)
    except Exception:
        continue
# Out:
# /var/folders/kg/yc3v1y_96vj9m5s_743c5vn00000gn/T/ipykernel_93784/2160831594.py:6: RuntimeWarning: divide by zero encountered in double_scalars
#   rs = up/down
# /var/folders/kg/yc3v1y_96vj9m5s_743c5vn00000gn/T/ipykernel_93784/2160831594.py:23: RuntimeWarning: divide by zero encountered in double_scalars
#   rs = up/down
# /var/folders/kg/yc3v1y_96vj9m5s_743c5vn00000gn/T/ipykernel_93784/2160831594.py:6: RuntimeWarning: divide by zero encountered in double_scalars
#   rs = up/down
# /var/folders/kg/yc3v1y_96vj9m5s_743c5vn00000gn/T/ipykernel_93784/2160831594.py:23: RuntimeWarning: divide by zero encountered in double_scalars
#   rs = up/down
# /var/folders/kg/yc3v1y_96vj9m5s_743c5vn00000gn/T/ipykernel_93784/2160831594.py:6: RuntimeWarning: divide by zero encountered in double_scalars
#   rs = up/down
# /var/folders/kg/yc3v1y_96vj9m5s_743c5vn00000gn/T/ipykernel_93784/2160831594.py:23: RuntimeWarning: divide by zero encountered in double_scalars
#   rs = up/down

# %% [markdown]
# ## Filter Our Market Data That Is Not Current

# %%
# Filter our market data that is not current.
dataframes = [df for df in dataframes if df.index[-1].date() == datetime.today().date()]

# %%
# Brief analysis.
largest_row_count = max([d.shape[0] for d in dataframes])
smallest_row_count = min([d.shape[0] for d in dataframes])

print(f'Largest Dataset: {largest_row_count}, Smallest Dataset: {smallest_row_count} (Target)')
# Out:
# Largest Dataset: 23999, Smallest Dataset: 13548 (Target)

# %%
# Concat all dataframes together, joined on index.
consolidated_dataset = reduce(lambda x, y: pd.concat([x, y], axis=1), dataframes)
# Drop all records where there are missing data from pairs.
consolidated_dataset = consolidated_dataset.dropna()

# %% [markdown]
# ## Train a Model

# %%
data: pd.DataFrame = consolidated_dataset.copy().reset_index()
input_feature_count: int = data.shape[1]
label_column_names: list = [c for c in data.columns if '__close_next' in c]
model = BifrostNeuralEngine(data=data,
                            autobootstrap_filename='../../data/binance_model.pt',
                            labels_column_names=label_column_names,
                            date_column_name='time') \
    .fit(epochs=50)
# Out:
# Epoch: 1, Loss: 0.031332772225141525 (Prev: -1): 100%|██████████| 50/50 [00:15<00:00,  3.26it/s]

# %% [markdown]
# ## Make Predictions

# %%
# Perform predictions on consolidated dataframe.
prediction_frame = consolidated_dataset.copy()[-100:]
pairs_to_predict = list(set([c.split('__')[0] for c in consolidated_dataset.columns]))

predictions = model.predict(x=prediction_frame.reset_index())
predictions.index = prediction_frame.index
predictions.columns = [c + '_pred' for c in predictions.columns]

original_frame_wih_predictions = pd.concat([predictions, prediction_frame], axis=1)

# %%
for pair in pairs_to_predict:
    original_frame_wih_predictions[[f'{pair}__close_next', f'{pair}__close_next_pred']].plot()
# Out:
# /Users/deanmartin/miniforge3/envs/pytorch/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:386: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)

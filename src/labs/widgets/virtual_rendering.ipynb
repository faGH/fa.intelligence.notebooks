# %% [markdown]
# # OpenAI Gym Virtual Rendering
# Understanding and creating utilities for 3d RGB arrays. Particularly we want to convert these to images and allow for rendering them to notebooks. We also want to stack these images to create videos.

# %%
from nes_py.wrappers import JoypadSpace
import gym_super_mario_bros
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT

# %% [markdown]
# ### Environment
# Create an OpenAI environment that produces an RGB array as an observation space.

# %%
env = gym_super_mario_bros.make('SuperMarioBros-v0')
env = JoypadSpace(env, SIMPLE_MOVEMENT)

# %% [markdown]
# Observe that the observation space is a 3D array. Height x Width x RGB.

# %%
env.observation_space.shape
# Out:
# (240, 256, 3)

# %% [markdown]
# Get the initial observation which should be good enough for this example.

# %%
observation = env.reset()

observation.shape
# Out:
# (240, 256, 3)

# %% [markdown]
# ### Image Conversion

# %% [markdown]
# Import imaging utilities.

# %%
# %run ./fa.intelligence.notebooks/utilities/common/imaging.ipynb

# %%
initial_observation = rgb_array_to_image(observation)

# %% [markdown]
# Render the image of the initial observation.

# %%
initial_observation
# Out:
# <PIL.Image.Image image mode=RGB size=256x240 at 0x22A88098D30>

# %% [markdown]
# Render a gif containing X count of random steps taken in the environment.

# %%
step_images = []
steps_to_record = 100
done = False

step_images.append(initial_observation)

for step_index in range(steps_to_record - 1):
    state, reward, done, info = env.step(env.action_space.sample())
    state_render = rgb_array_to_image(state)
    
    step_images.append(state_render)
    
gif_bytes = images_to_gif_bytes(step_images)

# %%
from IPython.display import Image, HTML

Image(gif_bytes)

# %% [markdown]
# HTML custom render for results.

# %%
import base64

# %%
# %%html
# <style>
#     .footer{
#         padding: 15px
#     }
#
#     .center{
#         text-align:center
#     }
#
#     .episode-container{
#         display: inline-block;
#         padding: 15px
#     }
#
#     .epi-title{
#         font-weight:bold
#     }
#
#     .epi-gif{
#         padding: 5px
#     }
# </style>
# Out:
# <style>
#     .footer{
#         padding: 15px
#     }
#
#     .center{
#         text-align:center
#     }
#
#     .episode-container{
#         display: inline-block;
#         padding: 15px
#     }
#
#     .epi-title{
#         font-weight:bold
#     }
#
#     .epi-gif{
#         padding: 5px
#     }
# </style>

# %%
experiment_name = 'OpenAI Mario RL Agent Training Results'

# Test data.
episodes = [gif_bytes, gif_bytes]
episodes_html = ''.join([ f'<div class="episode-container"><div class="epi-title">Ep X</div><div class="epi-gif"><img src="...{base64.b64encode(gif_bytes).decode()}" /></div><div>Reward: 0.00</div></div>' for e in episodes ])

display(HTML(f'<h1 class="center">{experiment_name}</h1><div class="center">{episodes_html}</div><div class="center footer">FrostAura Intelligence</div>'))
# Out:
# <h1 class="center">OpenAI Mario RL Agent Training Results</h1><div class="center"><div class="episode-container"><div class="epi-title">Ep X</div><div class="epi-gif"><img src="......" /></div><div>Reward: 0.00</div></div><div class="episode-container"><div class="epi-title">Ep X</div><div class="epi-gif"><img src="......" /></div><div>Reward: 0.00</div></div></div><div class="center footer">FrostAura Intelligence</div>

# %% [markdown]
# # Install Dependencies

# %% [markdown]
# ## External Dependencies

# %%
# !pip install yfinance pandas expiringdict swifter
# Out:
# Requirement already satisfied: yfinance in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (0.1.74)
# Requirement already satisfied: pandas in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (1.4.3)
# Requirement already satisfied: expiringdict in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (1.2.2)
# Requirement already satisfied: swifter in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (1.3.4)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: requests>=2.26 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from yfinance) (2.27.1)
# Requirement already satisfied: lxml>=4.5.1 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from yfinance) (4.6.3)
# Requirement already satisfied: numpy>=1.15 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from yfinance) (1.22.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\divanma\appdata\roaming\python\python39\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: bleach>=3.1.1 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from swifter) (4.1.0)
# Requirement already satisfied: cloudpickle>=0.2.2 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from swifter) (2.0.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from swifter) (7.6.5)
# Requirement already satisfied: dask[dataframe]>=2.10.0 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from swifter) (2022.9.0)
# Requirement already satisfied: tqdm>=4.33.0 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from swifter) (4.64.0)
# WARNING: Ignoring invalid distribution -ymupdf (c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymupdf (c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymupdf (c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymupdf (c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymupdf (c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymupdf (c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages)
# Requirement already satisfied: psutil>=5.6.6 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from swifter) (5.9.2)
# Requirement already satisfied: parso>0.4.0 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from swifter) (0.8.2)
# Requirement already satisfied: packaging in c:\users\divanma\appdata\roaming\python\python39\site-packages (from bleach>=3.1.1->swifter) (21.3)
# Requirement already satisfied: webencodings in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from bleach>=3.1.1->swifter) (0.5.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\divanma\appdata\roaming\python\python39\site-packages (from bleach>=3.1.1->swifter) (1.16.0)
# Requirement already satisfied: fsspec>=0.6.0 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (2022.8.2)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (6.0)
# Requirement already satisfied: toolz>=0.8.2 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (0.12.0)
# Requirement already satisfied: partd>=0.3.10 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (1.3.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from ipywidgets>=7.0.0->swifter) (5.1.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from ipywidgets>=7.0.0->swifter) (3.5.1)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from ipywidgets>=7.0.0->swifter) (6.4.1)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from ipywidgets>=7.0.0->swifter) (7.28.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from ipywidgets>=7.0.0->swifter) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from ipywidgets>=7.0.0->swifter) (1.0.2)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from ipywidgets>=7.0.0->swifter) (5.1.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from requests>=2.26->yfinance) (3.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from requests>=2.26->yfinance) (2022.5.18.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from requests>=2.26->yfinance) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from requests>=2.26->yfinance) (2.0.0)
# Requirement already satisfied: colorama in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from tqdm>=4.33.0->swifter) (0.4.4)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (1.4.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (0.1.3)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (6.1)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (7.0.6)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (3.0.20)
# Requirement already satisfied: pickleshare in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.7.5)
# Requirement already satisfied: backcall in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.2.0)
# Requirement already satisfied: decorator in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (4.4.2)
# Requirement already satisfied: setuptools>=18.5 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (58.2.0)
# Requirement already satisfied: pygments in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (2.10.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.18.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->swifter) (4.1.0)
# Requirement already satisfied: jupyter-core in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->swifter) (4.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\divanma\appdata\roaming\python\python39\site-packages (from packaging->bleach>=3.1.1->swifter) (3.0.9)
# Requirement already satisfied: locket in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from partd>=0.3.10->dask[dataframe]>=2.10.0->swifter) (1.0.0)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (6.4.4)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->swifter) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->swifter) (21.2.0)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (1.5.1)
# Requirement already satisfied: pyzmq>=13 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (22.3.0)
# Requirement already satisfied: entrypoints in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (0.3)
# Requirement already satisfied: pywin32>=1.0 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets>=7.0.0->swifter) (301)
# Requirement already satisfied: prometheus-client in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.11.0)
# Requirement already satisfied: argon2-cffi in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (21.1.0)
# Requirement already satisfied: jinja2 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (3.0.2)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (1.8.0)
# Requirement already satisfied: nbconvert in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (6.2.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.12.1)
# Requirement already satisfied: wcwidth in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.2.5)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (1.1.4)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (1.14.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (2.0.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (1.5.0)
# Requirement already satisfied: testpath in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.5.0)
# Requirement already satisfied: defusedxml in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.5.4)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.8.4)
# Requirement already satisfied: pycparser in c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (2.20)

# %% [markdown]
# ## FrostAura Dependencies

# %%
import os
import sys

USE_LOCAL_CODE: bool = True # NOTE: When changing this configuration, be sure to restart the interpreter in order to have sys path updates reflect.
directories_to_move_up: int = 2
current_executing_path: str = os.getcwd()
current_executing_path = current_executing_path.replace('\\', '/')
root_path: str = '/'.join(current_executing_path.split('/')[:-directories_to_move_up])

# Clean up.
# %pip uninstall frostaura -y
sys.path = [p for p in sys.path if p != root_path]

if USE_LOCAL_CODE:
    sys.path.append(root_path)
else:
    # %pip install -U --no-cache-dir frostaura
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ymupdf (c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymupdf (c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\divanma\.conda\envs\windows-ml-station\lib\site-packages)
# WARNING: Skipping frostaura as it is not installed.

# %% [markdown]
# # Import Dependencies

# %%
from frostaura.data_access import IPublicAssetDataAccess
from frostaura.data_access import YahooFinanceDataAccess
from frostaura.data_access import IPersonalAssetDataAccess
from frostaura.data_access import EasyEquitiesPersonalAssetDataAccess
from frostaura.data_access import IResourcesDataAccess
from frostaura.data_access import EmbeddedResourcesDataAccess
import pandas as pd

# %% [markdown]
# ## Logging

# %%
import logging

logging.basicConfig(level=logging.DEBUG)

# %% [markdown]
# # Usage

# %%
resource_data_access: IResourcesDataAccess = EmbeddedResourcesDataAccess()
personal_asset_data_access: IPersonalAssetDataAccess = EasyEquitiesPersonalAssetDataAccess(resource_data_access=resource_data_access,
                                                                         username='...',
                                                                         password='...')
instance: IPublicAssetDataAccess = YahooFinanceDataAccess()
symbol: str = 'SPY'

# %%
data: pd.DataFrame = instance.get_symbol_history(symbol=symbol)

data.head()
# Out:
# INFO:root:Fetching historical price movements for symbol "SPY".
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query2.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query2.finance.yahoo.com:443 "GET /v8/finance/chart/SPY?period1=-631159200&period2=1673874885&interval=1d&includePrePost=False&events=div%2Csplits HTTP/1.1" 200 None
#                  Open       High        Low      Close   Volume  Dividends  \
# Date
# 1993-01-29  25.236173  25.236173  25.110620  25.218237  1003200        0.0
# 1993-02-01  25.236165  25.397591  25.236165  25.397591   480500        0.0
# 1993-02-02  25.379643  25.469324  25.325834  25.451387   201300        0.0
# 1993-02-03  25.487266  25.738372  25.469330  25.720436   529400        0.0
# 1993-02-04  25.810130  25.881874  25.523151  25.828066   531500        0.0
#
#             Stock Splits
# Date
# 1993-01-29             0
# 1993-02-01             0
# 1993-02-02             0
# 1993-02-03             0
# 1993-02-04             0

# %%
supported_symbols: pd.DataFrame = personal_asset_data_access.get_supported_assets()
symbols_with_info: pd.DataFrame = instance.augment_symbols_info(symbols=supported_symbols)

symbols_with_info
# Out:
# INFO:root:Fetching EasyEquities supported symbols from a static source.
# INFO:root:Fetching embedded resource "c:/dev/P/fa.intelligence.notebooks/src/frostaura/resources/easy_equities_us_exclusions.json".
# INFO:root:Fetching embedded resource "c:/dev/P/fa.intelligence.notebooks/src/frostaura/resources/easy_equities_us_stocks.json".
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/ZS?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/ZM?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/ZTS?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/ZIMV?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/ZBH?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/Z?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/ZEN?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/ZBRA?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/YUM?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/DAO?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/YETI?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/XPO?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/XPEV?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/XNCR?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/WYNN?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/WRAP?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/WWE?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/WKHS?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/WDAY?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/WDS?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/WOLF?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/WNS?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/WIX?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/WMB?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/WPM?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/WAB?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/WDC?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/WFC?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/WB?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/WM?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/WMG?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/WBD?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/DIS?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/WMT?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/WD?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/WBA?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/VUZI?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/VNT?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/VOD?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/VMW?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/V?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/SPCE?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/VIPS?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/VTRS?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/VRTX?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/VZ?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/VRSK?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/VCEL?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/VEEV?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/VALE?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/USB?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/UBA?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/UEC?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/UPST?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/TIGR?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/U?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/UNH?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/X?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/UPS?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/UMC?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/QURE?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/UNP?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/UL?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/UAA?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/UCTT?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/ULTA?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/PATH?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/UI?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/UBER?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/TWTR?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/TWLO?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/HEAR?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/TRVG?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/TRIP?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/TCOM?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/TRMB?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/TREX?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/TRV?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/TMDX?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/TDG?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/TTD?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/TSCO?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/TPIC?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/TM?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/TTC?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/TMUS?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/TLRY?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/THO?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/TMO?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/TXN?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/TSLA?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/TME?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/TENB?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/TLS?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/TELL?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/TDOC?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/TECK?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/TTCF?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/TGT?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/TTWO?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/TAK?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/TSM?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/TROW?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/SNPS?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/SYF?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/SIVB?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/SUPN?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/SGHC?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/RUN?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/SPWR?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/SNDL?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/SU?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/SYK?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/LRN?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/SSYS?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/STNE?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/STM?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/SFIX?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/STEM?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/STLA?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/SBUX?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/SBLK?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/SWK?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/STAG?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/SQSP?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/SQ?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/SPT?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/SPOT?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/SRAD?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/SPLK?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/SPR?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/SWN?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/LUV?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/SCCO?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/SO?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/SOS?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/SONY?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/SONO?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/SLDP?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/SEDG?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/SOFI?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/SQM?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/SNOW?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/SNAP?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/SMAR?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/SWKS?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/SKY?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/SKLZ?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/SIRI?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/SPG?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/SBNY?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/SBSW?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/SSTK?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/SHOP?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/SHW?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/SHEL?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/NOW?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# ...
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/APPN?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/APPH?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/AR?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/AM?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/NLY?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/ADI?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/AMRS?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/AMGN?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/AME?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/AWK?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/AMT?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/AIG?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/AXP?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/AAL?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/AMBA?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/AMZN?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/MO?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/AYX?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/GOOG?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/GOOGL?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/ALNY?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/ALL?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/ALGN?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/BABA?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/ALB?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/AKAM?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/ABNB?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/APD?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/API?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/AEM?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/AGNC?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/AFRM?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/AVAV?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/AER?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/ACM?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/AMD?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/ADBE?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/ATVI?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/ACEV?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 2539
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/ACN?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/ABBV?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/ABT?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/AAON?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/MMM?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/DDD?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/TWOU?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/VNET?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/TXG?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
#                               name symbol  \
# 34     American Airlines Group Inc    AAL
# 5                         AAON Inc   AAON
# 48                       Apple Inc   AAPL
# 7                       Abbvie Inc   ABBV
# 21                      Airbnb Inc   ABNB
# ..                             ...    ...
# 661                    Zendesk Inc    ZEN
# 664                     Zimvie Inc   ZIMV
# 666  Zoom Video Communications Inc     ZM
# 667                    Zscaler Inc     ZS
# 665                     Zoetis Inc    ZTS
#
#                                                  quote
# 34   <frostaura.models.symbol_data.SymbolData objec...
# 5    <frostaura.models.symbol_data.SymbolData objec...
# 48   <frostaura.models.symbol_data.SymbolData objec...
# 7    <frostaura.models.symbol_data.SymbolData objec...
# 21   <frostaura.models.symbol_data.SymbolData objec...
# ..                                                 ...
# 661  <frostaura.models.symbol_data.SymbolData objec...
# 664  <frostaura.models.symbol_data.SymbolData objec...
# 666  <frostaura.models.symbol_data.SymbolData objec...
# 667  <frostaura.models.symbol_data.SymbolData objec...
# 665  <frostaura.models.symbol_data.SymbolData objec...
#
# [668 rows x 3 columns]

# %%
vars(symbols_with_info.quote[0])
# Out:
# {'symbol': 'TXG',
#  'company_name': '10x Genomics, Inc.',
#  'current_price': 43.22,
#  'eps': -0.802,
#  'annual_growth_projected': -1.162,
#  'current_yield_of_aaa_corporate_bonds': 4.27,
#  'pe_base_non_growth_company': 8.5,
#  'average_yield_of_aaa_corporate_bonds': 4.4}

# %% [markdown]
# # Install Dependencies

# %% [markdown]
# ## External Dependencies

# %%
# !pip install yfinance pandas expiringdict swifter
# Out:
# Requirement already satisfied: yfinance in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (0.1.74)
# Requirement already satisfied: pandas in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (1.3.3)
# Requirement already satisfied: expiringdict in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (1.2.2)
# Requirement already satisfied: swifter in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (1.3.4)
# Requirement already satisfied: requests>=2.26 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from yfinance) (2.26.0)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.5.1 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from yfinance) (4.6.3)
# Requirement already satisfied: numpy>=1.15 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from yfinance) (1.22.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from pandas) (2022.1)
# Requirement already satisfied: cloudpickle>=0.2.2 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from swifter) (2.0.0)
# Requirement already satisfied: bleach>=3.1.1 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from swifter) (4.1.0)
# Requirement already satisfied: psutil>=5.6.6 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from swifter) (5.9.1)
# Requirement already satisfied: parso>0.4.0 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from swifter) (0.8.2)
# Requirement already satisfied: dask[dataframe]>=2.10.0 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from swifter) (2022.8.1)
# Requirement already satisfied: ipywidgets>=7.0.0 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from swifter) (7.6.5)
# Requirement already satisfied: tqdm>=4.33.0 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from swifter) (4.62.3)
# Requirement already satisfied: webencodings in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from bleach>=3.1.1->swifter) (0.5.1)
# Requirement already satisfied: packaging in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from bleach>=3.1.1->swifter) (21.0)
# Requirement already satisfied: six>=1.9.0 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from bleach>=3.1.1->swifter) (1.15.0)
# Requirement already satisfied: fsspec>=0.6.0 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from dask[dataframe]>=2.10.0->swifter) (2022.8.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from dask[dataframe]>=2.10.0->swifter) (5.4.1)
# Requirement already satisfied: toolz>=0.8.2 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from dask[dataframe]>=2.10.0->swifter) (0.12.0)
# Requirement already satisfied: partd>=0.3.10 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from dask[dataframe]>=2.10.0->swifter) (1.3.0)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from ipywidgets>=7.0.0->swifter) (5.1.0)
# Requirement already satisfied: ipython>=4.0.0 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from ipywidgets>=7.0.0->swifter) (7.28.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from ipywidgets>=7.0.0->swifter) (1.0.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from ipywidgets>=7.0.0->swifter) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from ipywidgets>=7.0.0->swifter) (3.5.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from ipywidgets>=7.0.0->swifter) (6.4.1)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from ipywidgets>=7.0.0->swifter) (5.1.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from requests>=2.26->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from requests>=2.26->yfinance) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from requests>=2.26->yfinance) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from requests>=2.26->yfinance) (3.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (1.4.1)
# Requirement already satisfied: appnope in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (0.1.2)
# Requirement already satisfied: jupyter-client<8.0 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (7.0.5)
# Requirement already satisfied: tornado<7.0,>=4.2 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (6.2)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (0.1.3)
# Requirement already satisfied: decorator in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (5.1.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (3.0.20)
# Requirement already satisfied: backcall in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.2.0)
# Requirement already satisfied: pygments in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (2.10.0)
# Requirement already satisfied: pickleshare in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.7.5)
# Requirement already satisfied: pexpect>4.3 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.18.0)
# Requirement already satisfied: setuptools>=18.5 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (58.0.4)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->swifter) (4.0.1)
# Requirement already satisfied: jupyter-core in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->swifter) (4.8.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from packaging->bleach>=3.1.1->swifter) (2.4.7)
# Requirement already satisfied: locket in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from partd>=0.3.10->dask[dataframe]>=2.10.0->swifter) (1.0.0)
# Requirement already satisfied: notebook>=4.4.1 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (6.4.4)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->swifter) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->swifter) (21.2.0)
# Requirement already satisfied: nest-asyncio>=1.5 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (1.5.1)
# Requirement already satisfied: entrypoints in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (0.3)
# Requirement already satisfied: pyzmq>=13 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (22.3.0)
# Requirement already satisfied: jinja2 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (3.0.1)
# Requirement already satisfied: nbconvert in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (6.2.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.12.1)
# Requirement already satisfied: Send2Trash>=1.5.0 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (1.8.0)
# Requirement already satisfied: argon2-cffi in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (20.1.0)
# Requirement already satisfied: prometheus-client in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.11.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.2.5)
# Requirement already satisfied: cffi>=1.0.0 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (1.14.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (2.0.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (1.5.0)
# Requirement already satisfied: testpath in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.5.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.5.4)
# Requirement already satisfied: defusedxml in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.1.2)
# Requirement already satisfied: pycparser in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (2.20)
#
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## FrostAura Dependencies

# %%
import os
import sys

USE_LOCAL_CODE: bool = True # NOTE: When changing this configuration, be sure to restart the interpreter in order to have sys path updates reflect.
directories_to_move_up: int = 2
current_executing_path: str = os.getcwd()
current_executing_path = current_executing_path.replace('\\', '/')
root_path: str = '/'.join(current_executing_path.split('/')[:-directories_to_move_up])

# Clean up.
# %pip uninstall frostaura -y
sys.path = [p for p in sys.path if p != root_path]

if USE_LOCAL_CODE:
    sys.path.append(root_path)
else:
    # %pip install -U --no-cache-dir frostaura
# Out:
# WARNING: Skipping frostaura as it is not installed.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Import Dependencies

# %%
from frostaura.data_access import IPublicAssetDataAccess
from frostaura.data_access import YahooFinanceDataAccess
from frostaura.data_access import IPersonalAssetDataAccess
from frostaura.data_access import EasyEquitiesPersonalAssetDataAccess
from frostaura.data_access import IResourcesDataAccess
from frostaura.data_access import EmbeddedResourcesDataAccess
import pandas as pd

# %% [markdown]
# ## Logging

# %%
import logging

logging.basicConfig(level=logging.DEBUG)

# %% [markdown]
# # Usage

# %%
resource_data_access: IResourcesDataAccess = EmbeddedResourcesDataAccess()
personal_asset_data_access: IPersonalAssetDataAccess = EasyEquitiesPersonalAssetDataAccess(resource_data_access=resource_data_access,
                                                                         username='...',
                                                                         password='...')
instance: IPublicAssetDataAccess = YahooFinanceDataAccess()
symbol: str = 'SPY'

# %%
data: pd.DataFrame = instance.get_symbol_history(symbol=symbol)

data.head()
# Out:
# INFO:root:Fetching historical price movements for symbol "SPY".
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query2.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query2.finance.yahoo.com:443 "GET /v8/finance/chart/SPY?period1=-631159200&period2=1662635105&interval=1d&includePrePost=False&events=div%2Csplits HTTP/1.1" 200 None
#                  Open       High        Low      Close   Volume  Dividends  \
# Date
# 1993-01-29  25.456195  25.456195  25.329548  25.438103  1003200        0.0
# 1993-02-01  25.456173  25.619005  25.456173  25.619005   480500        0.0
# 1993-02-02  25.600935  25.691398  25.546658  25.673306   201300        0.0
# 1993-02-03  25.709480  25.962776  25.691388  25.944683   529400        0.0
# 1993-02-04  26.035147  26.107517  25.745667  26.053240   531500        0.0
#
#             Stock Splits
# Date
# 1993-01-29             0
# 1993-02-01             0
# 1993-02-02             0
# 1993-02-03             0
# 1993-02-04             0

# %%
supported_symbols: pd.DataFrame = personal_asset_data_access.get_supported_assets()[:50]
symbols_with_info: pd.DataFrame = instance.augment_symbols_info(symbols=supported_symbols)

symbols_with_info
# Out:
# INFO:root:Fetching EasyEquities supported symbols from a static source.
# INFO:root:Fetching embedded resource "/Users/deanmartin/Source/fa.intelligence.notebooks/frostaura/resources/easy_equities_us_exclusions.json".
# INFO:root:Fetching embedded resource "/Users/deanmartin/Source/fa.intelligence.notebooks/frostaura/resources/easy_equities_us_stocks.json".
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/TXG?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/VNET?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/TWOU?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/DDD?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/MMM?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/AAON?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/ABT?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/ABBV?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/ACN?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/ACEV?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 2529
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/ATVI?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/ADBE?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/AMD?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/ACM?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/AER?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/AVAV?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/AFRM?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/AGNC?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/AEM?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/API?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/APD?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/ABNB?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/AKAM?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/ALB?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/BABA?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/ALGN?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/ALL?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/ALNY?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/GOOGL?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/GOOG?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/AYX?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/MO?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/AMZN?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/AMBA?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/AAL?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/AXP?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/AIG?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/AMT?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/AWK?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/AME?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/AMGN?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/AMRS?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/ADI?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/NLY?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/AM?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/AR?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/APPH?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/APPN?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/AAPL?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): query1.finance.yahoo.com:443
# DEBUG:urllib3.connectionpool:https://query1.finance.yahoo.com:443 "GET /v10/finance/quoteSummary/AMAT?modules=assetProfile,defaultKeyStatistics,financialData,earningsTrend,price,summaryDetail HTTP/1.1" 200 None
#                                 name symbol  \
# 34       American Airlines Group Inc    AAL
# 5                           AAON Inc   AAON
# 48                         Apple Inc   AAPL
# 7                         Abbvie Inc   ABBV
# 21                        Airbnb Inc   ABNB
# 6                Abbott Laboratories    ABT
# 9   ACE Convergence Acquisition Corp   ACEV
# 13                             AECOM    ACM
# 8                 Accenture Plc-Cl A    ACN
# 11                 Adobe Systems Inc   ADBE
# 42                Analog Devices Inc    ADI
# 18        Agnico Eagle Mines Limited    AEM
# 14                AerCap Holdings NV    AER
# 16               Affirm Holdings Inc   AFRM
# 17              AGNC Investment Corp   AGNC
# 36      American International Group    AIG
# 22           Akamai Technologies Inc   AKAM
# 23             Albemarle Corporation    ALB
# 25              ALIGN TECHNOLOGY INC   ALGN
# 26                     Allstate Corp    ALL
# 27           Alnylam Pharmaceuticals   ALNY
# 44      Antero Midstream Corporation     AM
# 49             Applied Materials Inc   AMAT
# 33                    Ambarella Inc.   AMBA
# 12        Advanced Micro Devices Inc    AMD
# 39                        AMETEK Inc    AME
# 40                         Amgen Inc   AMGN
# 41                        Amyris Inc   AMRS
# 37               American Tower Corp    AMT
# 32                    Amazon.Com Inc   AMZN
# 20       Air Products & Chemical Inc    APD
# 19                         Agora Inc    API
# 46                    AppHarvest Inc   APPH
# 47                       Appian Corp   APPN
# 45             Antero Resources Corp     AR
# 10           Activision Blizzard Inc   ATVI
# 15                 AeroVironment Inc   AVAV
# 38       American Water Works Co Inc    AWK
# 35               American Express Co    AXP
# 30                       Alteryx Inc    AYX
# 24         Alibaba Group Holding Ltd   BABA
# 3                     3D Systems Inc    DDD
# 29                 Alphabet Inc-Cl C   GOOG
# 28                 Alphabet Inc-Cl A  GOOGL
# 4                              3M Co    MMM
# 31                  Altria Group Inc     MO
# 43     Annaly Capital Management Inc    NLY
# 2                             2U Inc   TWOU
# 0                   10X Genomics Inc    TXG
# 1                 21Vianet Group Inc   VNET
#
#                                                 quote
# 34  <frostaura.models.symbol_data.SymbolData objec...
# 5   <frostaura.models.symbol_data.SymbolData objec...
# 48  <frostaura.models.symbol_data.SymbolData objec...
# 7   <frostaura.models.symbol_data.SymbolData objec...
# 21  <frostaura.models.symbol_data.SymbolData objec...
# 6   <frostaura.models.symbol_data.SymbolData objec...
# 9   <frostaura.models.symbol_data.SymbolData objec...
# 13  <frostaura.models.symbol_data.SymbolData objec...
# 8   <frostaura.models.symbol_data.SymbolData objec...
# 11  <frostaura.models.symbol_data.SymbolData objec...
# 42  <frostaura.models.symbol_data.SymbolData objec...
# 18  <frostaura.models.symbol_data.SymbolData objec...
# 14  <frostaura.models.symbol_data.SymbolData objec...
# 16  <frostaura.models.symbol_data.SymbolData objec...
# 17  <frostaura.models.symbol_data.SymbolData objec...
# 36  <frostaura.models.symbol_data.SymbolData objec...
# 22  <frostaura.models.symbol_data.SymbolData objec...
# 23  <frostaura.models.symbol_data.SymbolData objec...
# 25  <frostaura.models.symbol_data.SymbolData objec...
# 26  <frostaura.models.symbol_data.SymbolData objec...
# 27  <frostaura.models.symbol_data.SymbolData objec...
# 44  <frostaura.models.symbol_data.SymbolData objec...
# 49  <frostaura.models.symbol_data.SymbolData objec...
# 33  <frostaura.models.symbol_data.SymbolData objec...
# 12  <frostaura.models.symbol_data.SymbolData objec...
# 39  <frostaura.models.symbol_data.SymbolData objec...
# 40  <frostaura.models.symbol_data.SymbolData objec...
# 41  <frostaura.models.symbol_data.SymbolData objec...
# 37  <frostaura.models.symbol_data.SymbolData objec...
# 32  <frostaura.models.symbol_data.SymbolData objec...
# 20  <frostaura.models.symbol_data.SymbolData objec...
# 19  <frostaura.models.symbol_data.SymbolData objec...
# 46  <frostaura.models.symbol_data.SymbolData objec...
# 47  <frostaura.models.symbol_data.SymbolData objec...
# 45  <frostaura.models.symbol_data.SymbolData objec...
# 10  <frostaura.models.symbol_data.SymbolData objec...
# 15  <frostaura.models.symbol_data.SymbolData objec...
# 38  <frostaura.models.symbol_data.SymbolData objec...
# 35  <frostaura.models.symbol_data.SymbolData objec...
# 30  <frostaura.models.symbol_data.SymbolData objec...
# 24  <frostaura.models.symbol_data.SymbolData objec...
# 3   <frostaura.models.symbol_data.SymbolData objec...
# 29  <frostaura.models.symbol_data.SymbolData objec...
# 28  <frostaura.models.symbol_data.SymbolData objec...
# 4   <frostaura.models.symbol_data.SymbolData objec...
# 31  <frostaura.models.symbol_data.SymbolData objec...
# 43  <frostaura.models.symbol_data.SymbolData objec...
# 2   <frostaura.models.symbol_data.SymbolData objec...
# 0   <frostaura.models.symbol_data.SymbolData objec...
# 1   <frostaura.models.symbol_data.SymbolData objec...

# %%
vars(symbols_with_info.quote[0])
# Out:
# {'symbol': 'TXG',
#  'eps': -0.802,
#  'annual_growth_projected': -1.162,
#  'current_yield_of_aaa_corporate_bonds': 4.27,
#  'pe_base_non_growth_company': 8.5,
#  'average_yield_of_aaa_corporate_bonds': 4.4}

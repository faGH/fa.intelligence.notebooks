# %% [markdown]
# # Install Dependencies

# %% [markdown]
# ## External Dependencies

# %%
# !pip install python-telegram-bot matplotlib seaborn prettytable pandas beautifulsoup4 yfinance expiringdict easy_equities_client
# Out:
# Requirement already satisfied: python-telegram-bot in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (13.13)
# Requirement already satisfied: matplotlib in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (3.4.3)
# Requirement already satisfied: seaborn in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (0.11.2)
# Requirement already satisfied: prettytable in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (3.3.0)
# Requirement already satisfied: pandas in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (1.3.3)
# Requirement already satisfied: beautifulsoup4 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (4.11.1)
# Requirement already satisfied: yfinance in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (0.1.74)
# Requirement already satisfied: expiringdict in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (1.2.2)
# Requirement already satisfied: easy_equities_client in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (0.5.0)
# Requirement already satisfied: tornado>=6.1 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from python-telegram-bot) (6.2)
# Requirement already satisfied: pytz>=2018.6 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from python-telegram-bot) (2022.1)
# Requirement already satisfied: certifi in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from python-telegram-bot) (2021.10.8)
# Requirement already satisfied: cachetools==4.2.2 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from python-telegram-bot) (4.2.2)
# Requirement already satisfied: APScheduler==3.6.3 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from python-telegram-bot) (3.6.3)
# Requirement already satisfied: six>=1.4.0 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from APScheduler==3.6.3->python-telegram-bot) (1.15.0)
# Requirement already satisfied: tzlocal>=1.2 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from APScheduler==3.6.3->python-telegram-bot) (4.2)
# Requirement already satisfied: setuptools>=0.7 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from APScheduler==3.6.3->python-telegram-bot) (58.0.4)
# Requirement already satisfied: cycler>=0.10 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from matplotlib) (8.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: numpy>=1.16 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from matplotlib) (1.22.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: scipy>=1.0 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from seaborn) (1.7.0)
# Requirement already satisfied: wcwidth in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from prettytable) (0.2.5)
# Requirement already satisfied: soupsieve>1.2 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from beautifulsoup4) (2.3.2.post1)
# Requirement already satisfied: requests>=2.26 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from yfinance) (2.26.0)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.5.1 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from yfinance) (4.6.3)
# Requirement already satisfied: bs4<0.0.2,>=0.0.1 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from easy_equities_client) (0.0.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from requests>=2.26->yfinance) (2.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from requests>=2.26->yfinance) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from requests>=2.26->yfinance) (3.1)
# Requirement already satisfied: pytz-deprecation-shim in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from tzlocal>=1.2->APScheduler==3.6.3->python-telegram-bot) (0.1.0.post0)
# Requirement already satisfied: tzdata in /Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages (from pytz-deprecation-shim->tzlocal>=1.2->APScheduler==3.6.3->python-telegram-bot) (2022.1)
#
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## FrostAura Dependencies

# %%
import os
import sys

USE_LOCAL_CODE: bool = True # NOTE: When changing this configuration, be sure to restart the interpreter in order to have sys path updates reflect.
directories_to_move_up: int = 2
current_executing_path: str = os.getcwd()
current_executing_path = current_executing_path.replace('\\', '/')
root_path: str = '/'.join(current_executing_path.split('/')[:-directories_to_move_up])

# Clean up.
# %pip uninstall frostaura -y
sys.path = [p for p in sys.path if p != root_path]

if USE_LOCAL_CODE:
    sys.path.append(root_path)
else:
    # %pip install -U --no-cache-dir frostaura
# Out:
# WARNING: Skipping frostaura as it is not installed.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Import Dependencies

# %%
from frostaura.managers import IAssetReportingManager
from frostaura.managers import PublicAssetReportingManager
from frostaura.data_access import IResourcesDataAccess
from frostaura.data_access import EmbeddedResourcesDataAccess
from frostaura.data_access import IPersonalAssetDataAccess
from frostaura.data_access import EasyEquitiesPersonalAssetDataAccess
from frostaura.data_access import IPublicAssetDataAccess
from frostaura.data_access import YahooFinanceDataAccess
from frostaura.data_access import HtmlResourcesDataAccess
from frostaura.engines import IAssetValuationEngine
from frostaura.engines import GrahamValuationEngine
from frostaura.engines import IVisualizationEngine
from frostaura.engines import FrostAuraVisualizationEngine
from frostaura.data_access import INotificationsDataAccess
from frostaura.data_access import TelegramNotificationsDataAccess

# %% [markdown]
# # Usage

# %%
config: dict = {}
resource_data_access: IResourcesDataAccess = EmbeddedResourcesDataAccess()
personal_asset_data_access: IPersonalAssetDataAccess = EasyEquitiesPersonalAssetDataAccess(resource_data_access=resource_data_access,
                                                                                           username=None,
                                                                                           password=None)
public_asset_data_access: IPublicAssetDataAccess = YahooFinanceDataAccess()
html_data_access: IResourcesDataAccess = HtmlResourcesDataAccess()
asset_valuation_engine: IAssetValuationEngine = GrahamValuationEngine(html_data_access=html_data_access, public_asset_data_access=public_asset_data_access)
visualization_engine: IVisualizationEngine = FrostAuraVisualizationEngine()
bot_token = '5535601062:AAGpXCCTWa8OBajV3AeTPrmIOIFjPi_H3p8'
fa_finances_public_chat_id: str = '-622524519'
dean_martin_personal_chat_id: str = '1551490751'
public_notification_data_access: INotificationsDataAccess = TelegramNotificationsDataAccess(bot_token=bot_token,
                                                                                            chat_id=dean_martin_personal_chat_id)
public_asset_data_access: IPublicAssetDataAccess = YahooFinanceDataAccess()
instance: IAssetReportingManager = PublicAssetReportingManager(personal_asset_data_access=personal_asset_data_access,
                                                               asset_valuation_engine=asset_valuation_engine,
                                                               visualization_engine=visualization_engine,
                                                               public_notification_data_access=public_notification_data_access,
                                                               public_asset_data_access=public_asset_data_access)

# %%
with public_notification_data_access:
    symbol_data = instance.send_reports()
# Out:
# WARNING:root:No item with the key "TXG-history" existed in the cache.
# WARNING:root:No item with the key "VNET-history" existed in the cache.
# WARNING:root:No item with the key "TWOU-history" existed in the cache.
# WARNING:root:No item with the key "DDD-history" existed in the cache.
# WARNING:root:No item with the key "MMM-history" existed in the cache.
# WARNING:root:No item with the key "AAON-history" existed in the cache.
# WARNING:root:No item with the key "ABT-history" existed in the cache.
# WARNING:root:No item with the key "ABBV-history" existed in the cache.
# WARNING:root:No item with the key "ACN-history" existed in the cache.
# WARNING:root:No item with the key "ACEV-history" existed in the cache.
# WARNING:root:No item with the key "ATVI-history" existed in the cache.
# WARNING:root:No item with the key "ADBE-history" existed in the cache.
# WARNING:root:No item with the key "ACEV-data" existed in the cache.
# WARNING:root:No item with the key "TXG-data" existed in the cache.
# WARNING:root:No item with the key "VNET-data" existed in the cache.
# WARNING:root:No item with the key "TWOU-data" existed in the cache.
# WARNING:root:No item with the key "ACN-data" existed in the cache.
# WARNING:root:No item with the key "DDD-data" existed in the cache.
# WARNING:root:No item with the key "ABBV-data" existed in the cache.
# WARNING:root:No item with the key "ATVI-data" existed in the cache.
# WARNING:root:No item with the key "AAON-data" existed in the cache.
# WARNING:root:No item with the key "ADBE-data" existed in the cache.
# WARNING:root:No item with the key "ABT-data" existed in the cache.
# WARNING:root:No item with the key "MMM-data" existed in the cache.
# ERROR:telegram.ext.updater:Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# ERROR:telegram.ext.dispatcher:No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/updater.py", line 651, in _network_loop_retry
#     if not action_cb():
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/updater.py", line 602, in polling_action_cb
#     updates = self.bot.get_updates(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/extbot.py", line 226, in get_updates
#     updates = super().get_updates(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 133, in decorator
#     result = func(*args, **kwargs)
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 3057, in get_updates
#     self._post(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 298, in _post
#     return self.request.post(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/utils/request.py", line 361, in post
#     result = self._request_wrapper(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/utils/request.py", line 283, in _request_wrapper
#     raise Conflict(message)
# telegram.error.Conflict: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# ERROR:telegram.ext.updater:Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# ERROR:telegram.ext.dispatcher:No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/updater.py", line 651, in _network_loop_retry
#     if not action_cb():
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/updater.py", line 602, in polling_action_cb
#     updates = self.bot.get_updates(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/extbot.py", line 226, in get_updates
#     updates = super().get_updates(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 133, in decorator
#     result = func(*args, **kwargs)
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 3057, in get_updates
#     self._post(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 298, in _post
#     return self.request.post(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/utils/request.py", line 361, in post
#     result = self._request_wrapper(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/utils/request.py", line 283, in _request_wrapper
#     raise Conflict(message)
# telegram.error.Conflict: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# ERROR:telegram.ext.updater:Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# ERROR:telegram.ext.dispatcher:No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/updater.py", line 651, in _network_loop_retry
#     if not action_cb():
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/updater.py", line 602, in polling_action_cb
#     updates = self.bot.get_updates(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/extbot.py", line 226, in get_updates
#     updates = super().get_updates(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 133, in decorator
#     result = func(*args, **kwargs)
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 3057, in get_updates
#     self._post(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 298, in _post
#     return self.request.post(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/utils/request.py", line 361, in post
#     result = self._request_wrapper(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/utils/request.py", line 283, in _request_wrapper
#     raise Conflict(message)
# telegram.error.Conflict: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# WARNING:root:Error valuating symbol "ACEV": 'NoneType' object has no attribute 'loc'
# WARNING:root:No item with the key "ADVIHUA-history" existed in the cache.
# WARNING:root:No item with the key "AMD-history" existed in the cache.
# WARNING:root:No item with the key "ADVIHUA-data" existed in the cache.
# - ADVIHUA: No data found, symbol may be delisted
# WARNING:root:Error valuating symbol "VNET": could not convert string to float: '-'
# WARNING:root:No item with the key "ACM-history" existed in the cache.
# WARNING:root:Error valuating symbol "TXG": could not convert string to float: '-'
# WARNING:root:No item with the key "AER-history" existed in the cache.
# WARNING:root:No item with the key "AVAV-history" existed in the cache.
# WARNING:root:No item with the key "AFRM-history" existed in the cache.
# WARNING:root:No item with the key "AGNC-history" existed in the cache.
# WARNING:root:Error valuating symbol "TWOU": could not convert string to float: '-'
# WARNING:root:No item with the key "AEM-history" existed in the cache.
# WARNING:root:No item with the key "API-history" existed in the cache.
# WARNING:root:No item with the key "APD-history" existed in the cache.
# WARNING:root:No item with the key "ABNB-history" existed in the cache.
# WARNING:root:No item with the key "AKAM-history" existed in the cache.
# WARNING:root:No item with the key "AFRM-data" existed in the cache.
# ERROR:telegram.ext.updater:Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# ERROR:telegram.ext.dispatcher:No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/updater.py", line 651, in _network_loop_retry
#     if not action_cb():
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/updater.py", line 602, in polling_action_cb
#     updates = self.bot.get_updates(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/extbot.py", line 226, in get_updates
#     updates = super().get_updates(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 133, in decorator
#     result = func(*args, **kwargs)
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 3057, in get_updates
#     self._post(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 298, in _post
#     return self.request.post(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/utils/request.py", line 361, in post
#     result = self._request_wrapper(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/utils/request.py", line 283, in _request_wrapper
#     raise Conflict(message)
# telegram.error.Conflict: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# WARNING:root:No item with the key "AMD-data" existed in the cache.
# WARNING:root:No item with the key "API-data" existed in the cache.
# WARNING:root:No item with the key "ACM-data" existed in the cache.
# WARNING:root:No item with the key "ABNB-data" existed in the cache.
# WARNING:root:No item with the key "AER-data" existed in the cache.
# WARNING:root:No item with the key "AVAV-data" existed in the cache.
# WARNING:root:No item with the key "AGNC-data" existed in the cache.
# WARNING:root:No item with the key "AKAM-data" existed in the cache.
# WARNING:root:No item with the key "APD-data" existed in the cache.
# WARNING:root:No item with the key "AEM-data" existed in the cache.
# ERROR:telegram.ext.updater:Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# ERROR:telegram.ext.dispatcher:No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/updater.py", line 651, in _network_loop_retry
#     if not action_cb():
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/updater.py", line 602, in polling_action_cb
#     updates = self.bot.get_updates(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/extbot.py", line 226, in get_updates
#     updates = super().get_updates(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 133, in decorator
#     result = func(*args, **kwargs)
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 3057, in get_updates
#     self._post(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 298, in _post
#     return self.request.post(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/utils/request.py", line 361, in post
#     result = self._request_wrapper(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/utils/request.py", line 283, in _request_wrapper
#     raise Conflict(message)
# telegram.error.Conflict: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# WARNING:root:Error valuating symbol "ADVIHUA": 'NoneType' object has no attribute 'loc'
# WARNING:root:No item with the key "ALB-history" existed in the cache.
# WARNING:root:No item with the key "ALB-data" existed in the cache.
# WARNING:root:Error valuating symbol "AFRM": could not convert string to float: '-'
# WARNING:root:No item with the key "BABA-history" existed in the cache.
# WARNING:root:Error valuating symbol "API": could not convert string to float: '-'
# WARNING:root:No item with the key "ALGN-history" existed in the cache.
# WARNING:root:Error valuating symbol "AVAV": could not convert string to float: '-'
# WARNING:root:No item with the key "ALL-history" existed in the cache.
# WARNING:root:Error valuating symbol "AGNC": could not convert string to float: '-'
# WARNING:root:No item with the key "ALNY-history" existed in the cache.
# WARNING:root:No item with the key "GOOGL-history" existed in the cache.
# WARNING:root:No item with the key "BABA-data" existed in the cache.
# WARNING:root:Error valuating symbol "AER": could not convert string to float: '-'
# WARNING:root:No item with the key "GOOG-history" existed in the cache.
# WARNING:root:No item with the key "AYX-history" existed in the cache.
# WARNING:root:No item with the key "MO-history" existed in the cache.
# ERROR:telegram.ext.updater:Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# ERROR:telegram.ext.dispatcher:No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/updater.py", line 651, in _network_loop_retry
#     if not action_cb():
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/updater.py", line 602, in polling_action_cb
#     updates = self.bot.get_updates(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/extbot.py", line 226, in get_updates
#     updates = super().get_updates(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 133, in decorator
#     result = func(*args, **kwargs)
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 3057, in get_updates
#     self._post(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 298, in _post
#     return self.request.post(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/utils/request.py", line 361, in post
#     result = self._request_wrapper(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/utils/request.py", line 283, in _request_wrapper
#     raise Conflict(message)
# telegram.error.Conflict: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# WARNING:root:No item with the key "AMZN-history" existed in the cache.
# WARNING:root:No item with the key "ALGN-data" existed in the cache.
# WARNING:root:No item with the key "AMBA-history" existed in the cache.
# WARNING:root:No item with the key "AAL-history" existed in the cache.
# WARNING:root:No item with the key "ALNY-data" existed in the cache.
# WARNING:root:No item with the key "ALL-data" existed in the cache.
# WARNING:root:No item with the key "GOOGL-data" existed in the cache.
# WARNING:root:No item with the key "AYX-data" existed in the cache.
# WARNING:root:No item with the key "GOOG-data" existed in the cache.
# WARNING:root:No item with the key "AMBA-data" existed in the cache.
# WARNING:root:No item with the key "AMZN-data" existed in the cache.
# WARNING:root:No item with the key "AAL-data" existed in the cache.
# WARNING:root:No item with the key "MO-data" existed in the cache.
# WARNING:root:No item with the key "AXP-history" existed in the cache.
# WARNING:root:No item with the key "AXP-data" existed in the cache.
# WARNING:root:Error valuating symbol "AYX": could not convert string to float: '-'
# WARNING:root:No item with the key "AIG-history" existed in the cache.
# WARNING:root:No item with the key "AMT-history" existed in the cache.
# WARNING:root:No item with the key "AWK-history" existed in the cache.
# ERROR:telegram.ext.updater:Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# ERROR:telegram.ext.dispatcher:No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/updater.py", line 651, in _network_loop_retry
#     if not action_cb():
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/updater.py", line 602, in polling_action_cb
#     updates = self.bot.get_updates(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/extbot.py", line 226, in get_updates
#     updates = super().get_updates(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 133, in decorator
#     result = func(*args, **kwargs)
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 3057, in get_updates
#     self._post(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 298, in _post
#     return self.request.post(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/utils/request.py", line 361, in post
#     result = self._request_wrapper(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/utils/request.py", line 283, in _request_wrapper
#     raise Conflict(message)
# telegram.error.Conflict: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# WARNING:root:Error valuating symbol "ALNY": could not convert string to float: '-'
# WARNING:root:No item with the key "AME-history" existed in the cache.
# WARNING:root:No item with the key "AMGN-history" existed in the cache.
# WARNING:root:No item with the key "AMT-data" existed in the cache.
# WARNING:root:Error valuating symbol "AMBA": could not convert string to float: '-'
# WARNING:root:No item with the key "AMRS-history" existed in the cache.
# WARNING:root:No item with the key "ADI-history" existed in the cache.
# WARNING:root:No item with the key "AWK-data" existed in the cache.
# WARNING:root:No item with the key "NLY-history" existed in the cache.
# WARNING:root:No item with the key "AM-history" existed in the cache.
# WARNING:root:No item with the key "AIG-data" existed in the cache.
# WARNING:root:Error valuating symbol "AAL": could not convert string to float: '-'
# WARNING:root:No item with the key "AR-history" existed in the cache.
# WARNING:root:No item with the key "AMRS-data" existed in the cache.
# WARNING:root:No item with the key "AME-data" existed in the cache.
# WARNING:root:No item with the key "AMGN-data" existed in the cache.
# WARNING:root:No item with the key "APPH-history" existed in the cache.
# WARNING:root:No item with the key "ADI-data" existed in the cache.
# WARNING:root:No item with the key "AM-data" existed in the cache.
# WARNING:root:No item with the key "NLY-data" existed in the cache.
# WARNING:root:No item with the key "APPH-data" existed in the cache.
# WARNING:root:No item with the key "AR-data" existed in the cache.
# ERROR:telegram.ext.updater:Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# ERROR:telegram.ext.dispatcher:No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/updater.py", line 651, in _network_loop_retry
#     if not action_cb():
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/updater.py", line 602, in polling_action_cb
#     updates = self.bot.get_updates(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/extbot.py", line 226, in get_updates
#     updates = super().get_updates(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 133, in decorator
#     result = func(*args, **kwargs)
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 3057, in get_updates
#     self._post(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 298, in _post
#     return self.request.post(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/utils/request.py", line 361, in post
#     result = self._request_wrapper(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/utils/request.py", line 283, in _request_wrapper
#     raise Conflict(message)
# telegram.error.Conflict: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# ERROR:telegram.ext.updater:Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# ERROR:telegram.ext.dispatcher:No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/updater.py", line 651, in _network_loop_retry
#     if not action_cb():
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/updater.py", line 602, in polling_action_cb
#     updates = self.bot.get_updates(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/extbot.py", line 226, in get_updates
#     updates = super().get_updates(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 133, in decorator
#     result = func(*args, **kwargs)
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 3057, in get_updates
#     self._post(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 298, in _post
#     return self.request.post(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/utils/request.py", line 361, in post
#     result = self._request_wrapper(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/utils/request.py", line 283, in _request_wrapper
#     raise Conflict(message)
# telegram.error.Conflict: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# WARNING:root:No item with the key "APPN-history" existed in the cache.
# WARNING:root:No item with the key "APPN-data" existed in the cache.
# WARNING:root:No item with the key "AAPL-history" existed in the cache.
# WARNING:root:Error valuating symbol "AMRS": could not convert string to float: '-'
# WARNING:root:No item with the key "AMAT-history" existed in the cache.
# WARNING:root:No item with the key "APP-history" existed in the cache.
# WARNING:root:No item with the key "MT-history" existed in the cache.
# WARNING:root:No item with the key "ARCH-history" existed in the cache.
# WARNING:root:No item with the key "ADM-history" existed in the cache.
# WARNING:root:No item with the key "APP-data" existed in the cache.
# WARNING:root:No item with the key "ARVL-history" existed in the cache.
# WARNING:root:No item with the key "AAPL-data" existed in the cache.
# WARNING:root:Error valuating symbol "APPH": could not convert string to float: '-'
# WARNING:root:No item with the key "ASAN-history" existed in the cache.
# WARNING:root:No item with the key "ASPBLBU-history" existed in the cache.
# WARNING:root:No item with the key "AMAT-data" existed in the cache.
# WARNING:root:No item with the key "ARCH-data" existed in the cache.
# WARNING:root:No item with the key "MT-data" existed in the cache.
# WARNING:root:Error valuating symbol "AR": could not convert string to float: '-'
# WARNING:root:No item with the key "ASML-history" existed in the cache.
# WARNING:root:No item with the key "ASAN-data" existed in the cache.
# WARNING:root:No item with the key "ARVL-data" existed in the cache.
# WARNING:root:No item with the key "ASPBLBU-data" existed in the cache.
# - ASPBLBU: No data found, symbol may be delisted
# WARNING:root:No item with the key "AZN-history" existed in the cache.
# WARNING:root:No item with the key "ADM-data" existed in the cache.
# WARNING:root:No item with the key "ASML-data" existed in the cache.
# WARNING:root:No item with the key "AZN-data" existed in the cache.
# ERROR:telegram.ext.updater:Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# ERROR:telegram.ext.dispatcher:No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/updater.py", line 651, in _network_loop_retry
#     if not action_cb():
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/updater.py", line 602, in polling_action_cb
#     updates = self.bot.get_updates(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/extbot.py", line 226, in get_updates
#     updates = super().get_updates(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 133, in decorator
#     result = func(*args, **kwargs)
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 3057, in get_updates
#     self._post(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 298, in _post
#     return self.request.post(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/utils/request.py", line 361, in post
#     result = self._request_wrapper(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/utils/request.py", line 283, in _request_wrapper
#     raise Conflict(message)
# telegram.error.Conflict: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# ERROR:telegram.ext.updater:Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# ERROR:telegram.ext.dispatcher:No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/updater.py", line 651, in _network_loop_retry
#     if not action_cb():
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/updater.py", line 602, in polling_action_cb
#     updates = self.bot.get_updates(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/extbot.py", line 226, in get_updates
#     updates = super().get_updates(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 133, in decorator
#     result = func(*args, **kwargs)
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 3057, in get_updates
#     self._post(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 298, in _post
#     return self.request.post(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/utils/request.py", line 361, in post
#     result = self._request_wrapper(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/utils/request.py", line 283, in _request_wrapper
#     raise Conflict(message)
# telegram.error.Conflict: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# WARNING:root:Error valuating symbol "APPN": could not convert string to float: '-'
# WARNING:root:No item with the key "T-history" existed in the cache.
# WARNING:root:Error valuating symbol "APP": could not convert string to float: '-'
# WARNING:root:No item with the key "ATER-history" existed in the cache.
# WARNING:root:No item with the key "T-data" existed in the cache.
# WARNING:root:Error valuating symbol "ASPBLBU": 'NoneType' object has no attribute 'loc'
# WARNING:root:No item with the key "TEAM-history" existed in the cache.
# WARNING:root:No item with the key "ATER-data" existed in the cache.
# WARNING:root:Error valuating symbol "ARCH": could not convert string to float: '-'
# WARNING:root:No item with the key "ADSK-history" existed in the cache.
# WARNING:root:Error valuating symbol "MT": could not convert string to float: '-'
# WARNING:root:No item with the key "ADP-history" existed in the cache.
# WARNING:root:No item with the key "AVLR-history" existed in the cache.
# WARNING:root:No item with the key "BTG-history" existed in the cache.
# WARNING:root:Error valuating symbol "ASAN": could not convert string to float: '-'
# WARNING:root:No item with the key "BIDU-history" existed in the cache.
# WARNING:root:No item with the key "TEAM-data" existed in the cache.
# WARNING:root:Error valuating symbol "ARVL": could not convert string to float: '-'
# WARNING:root:No item with the key "BAND-history" existed in the cache.
# WARNING:root:No item with the key "AVLR-data" existed in the cache.
# WARNING:root:No item with the key "ADP-data" existed in the cache.
# WARNING:root:No item with the key "BAND-data" existed in the cache.
# WARNING:root:No item with the key "BTG-data" existed in the cache.
# WARNING:root:No item with the key "BIDU-data" existed in the cache.
# WARNING:root:No item with the key "ADSK-data" existed in the cache.
# WARNING:root:No item with the key "BAC-history" existed in the cache.
# WARNING:root:Error valuating symbol "AZN": could not convert string to float: '-'
# WARNING:root:No item with the key "BK-history" existed in the cache.
# WARNING:root:No item with the key "BZUN-history" existed in the cache.
# WARNING:root:No item with the key "BAC-data" existed in the cache.
# WARNING:root:No item with the key "BZUN-data" existed in the cache.
# ERROR:telegram.ext.updater:Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# ERROR:telegram.ext.dispatcher:No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/updater.py", line 651, in _network_loop_retry
#     if not action_cb():
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/updater.py", line 602, in polling_action_cb
#     updates = self.bot.get_updates(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/extbot.py", line 226, in get_updates
#     updates = super().get_updates(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 133, in decorator
#     result = func(*args, **kwargs)
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 3057, in get_updates
#     self._post(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 298, in _post
#     return self.request.post(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/utils/request.py", line 361, in post
#     result = self._request_wrapper(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/utils/request.py", line 283, in _request_wrapper
#     raise Conflict(message)
# telegram.error.Conflict: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# WARNING:root:No item with the key "BK-data" existed in the cache.
# WARNING:root:No item with the key "BCS-history" existed in the cache.
# WARNING:root:Error valuating symbol "ATER": could not convert string to float: '-'
# WARNING:root:No item with the key "GOLD-history" existed in the cache.
# WARNING:root:Error valuating symbol "TEAM": could not convert string to float: '-'
# WARNING:root:No item with the key "BHC-history" existed in the cache.
# WARNING:root:No item with the key "BCS-data" existed in the cache.
# WARNING:root:Error valuating symbol "AVLR": could not convert string to float: '-'
# WARNING:root:No item with the key "BEAM-history" existed in the cache.
# WARNING:root:No item with the key "GOLD-data" existed in the cache.
# WARNING:root:Error valuating symbol "BIDU": could not convert string to float: '-'
# WARNING:root:No item with the key "BBBY-history" existed in the cache.
# WARNING:root:No item with the key "BRKB-history" existed in the cache.
# WARNING:root:No item with the key "BYND-history" existed in the cache.
# WARNING:root:No item with the key "BEAM-data" existed in the cache.
# WARNING:root:No item with the key "BHP-history" existed in the cache.
# WARNING:root:No item with the key "BHC-data" existed in the cache.
# WARNING:root:No item with the key "BRKB-data" existed in the cache.
# ERROR:telegram.ext.updater:Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# ERROR:telegram.ext.dispatcher:No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/updater.py", line 651, in _network_loop_retry
#     if not action_cb():
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/updater.py", line 602, in polling_action_cb
#     updates = self.bot.get_updates(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/extbot.py", line 226, in get_updates
#     updates = super().get_updates(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 133, in decorator
#     result = func(*args, **kwargs)
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 3057, in get_updates
#     self._post(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 298, in _post
#     return self.request.post(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/utils/request.py", line 361, in post
#     result = self._request_wrapper(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/utils/request.py", line 283, in _request_wrapper
#     raise Conflict(message)
# telegram.error.Conflict: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# - BRKB: No data found, symbol may be delisted
# WARNING:root:Error valuating symbol "BAND": could not convert string to float: '-'
# WARNING:root:No item with the key "BILI-history" existed in the cache.
# WARNING:root:No item with the key "BYND-data" existed in the cache.
# WARNING:root:No item with the key "BBBY-data" existed in the cache.
# WARNING:root:No item with the key "BILI-data" existed in the cache.
# WARNING:root:No item with the key "BILL-history" existed in the cache.
# WARNING:root:No item with the key "BHP-data" existed in the cache.
# WARNING:root:Error valuating symbol "BZUN": could not convert string to float: '-'
# WARNING:root:No item with the key "BIIB-history" existed in the cache.
# WARNING:root:No item with the key "BILL-data" existed in the cache.
# WARNING:root:No item with the key "BIIB-data" existed in the cache.
# WARNING:root:No item with the key "BMRN-history" existed in the cache.
# WARNING:root:No item with the key "BMRN-data" existed in the cache.
# ERROR:telegram.ext.updater:Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# ERROR:telegram.ext.dispatcher:No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/updater.py", line 651, in _network_loop_retry
#     if not action_cb():
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/updater.py", line 602, in polling_action_cb
#     updates = self.bot.get_updates(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/extbot.py", line 226, in get_updates
#     updates = super().get_updates(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 133, in decorator
#     result = func(*args, **kwargs)
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 3057, in get_updates
#     self._post(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 298, in _post
#     return self.request.post(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/utils/request.py", line 361, in post
#     result = self._request_wrapper(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/utils/request.py", line 283, in _request_wrapper
#     raise Conflict(message)
# telegram.error.Conflict: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# WARNING:root:Error valuating symbol "BRKB": 'NoneType' object has no attribute 'loc'
# WARNING:root:No item with the key "BNGO-history" existed in the cache.
# WARNING:root:No item with the key "BNGO-data" existed in the cache.
# ERROR:telegram.ext.updater:Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# ERROR:telegram.ext.dispatcher:No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/updater.py", line 651, in _network_loop_retry
#     if not action_cb():
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/updater.py", line 602, in polling_action_cb
#     updates = self.bot.get_updates(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/extbot.py", line 226, in get_updates
#     updates = super().get_updates(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 133, in decorator
#     result = func(*args, **kwargs)
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 3057, in get_updates
#     self._post(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 298, in _post
#     return self.request.post(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/utils/request.py", line 361, in post
#     result = self._request_wrapper(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/utils/request.py", line 283, in _request_wrapper
#     raise Conflict(message)
# telegram.error.Conflict: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# WARNING:root:No item with the key "BNTX-history" existed in the cache.
# WARNING:root:No item with the key "BTAI-history" existed in the cache.
# WARNING:root:No item with the key "BNTX-data" existed in the cache.
# WARNING:root:No item with the key "BTCM-history" existed in the cache.
# WARNING:root:Error valuating symbol "BBBY": could not convert string to float: '-'
# WARNING:root:No item with the key "BDTX-history" existed in the cache.
# WARNING:root:Error valuating symbol "BYND": could not convert string to float: '-'
# WARNING:root:No item with the key "BLK-history" existed in the cache.
# WARNING:root:No item with the key "BTAI-data" existed in the cache.
# WARNING:root:Error valuating symbol "BEAM": could not convert string to float: '-'
# WARNING:root:No item with the key "BLNK-history" existed in the cache.
# WARNING:root:No item with the key "BDTX-data" existed in the cache.
# WARNING:root:No item with the key "BTCM-data" existed in the cache.
# WARNING:root:No item with the key "BLK-data" existed in the cache.
# WARNING:root:No item with the key "BLNK-data" existed in the cache.
# WARNING:root:No item with the key "BA-history" existed in the cache.
# WARNING:root:Error valuating symbol "BILI": could not convert string to float: '-'
# WARNING:root:No item with the key "BKNG-history" existed in the cache.
# WARNING:root:No item with the key "SAM-history" existed in the cache.
# WARNING:root:No item with the key "BKNG-data" existed in the cache.
# WARNING:root:Error valuating symbol "BMRN": could not convert string to float: '-'
# WARNING:root:No item with the key "BOC-history" existed in the cache.
# WARNING:root:No item with the key "BA-data" existed in the cache.
# WARNING:root:No item with the key "SAM-data" existed in the cache.
# WARNING:root:Error valuating symbol "BILL": 'NoneType' object has no attribute 'loc'
# WARNING:root:No item with the key "BSX-history" existed in the cache.
# WARNING:root:No item with the key "BOC-data" existed in the cache.
# WARNING:root:No item with the key "BSX-data" existed in the cache.
# ERROR:telegram.ext.updater:Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# ERROR:telegram.ext.dispatcher:No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/updater.py", line 651, in _network_loop_retry
#     if not action_cb():
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/updater.py", line 602, in polling_action_cb
#     updates = self.bot.get_updates(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/extbot.py", line 226, in get_updates
#     updates = super().get_updates(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 133, in decorator
#     result = func(*args, **kwargs)
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 3057, in get_updates
#     self._post(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 298, in _post
#     return self.request.post(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/utils/request.py", line 361, in post
#     result = self._request_wrapper(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/utils/request.py", line 283, in _request_wrapper
#     raise Conflict(message)
# telegram.error.Conflict: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# WARNING:root:Error valuating symbol "BNGO": could not convert string to float: '-'
# WARNING:root:No item with the key "BOX-history" existed in the cache.
# WARNING:root:Error valuating symbol "BNTX": could not convert string to float: '-'
# WARNING:root:No item with the key "BYD-history" existed in the cache.
# WARNING:root:No item with the key "BOX-data" existed in the cache.
# WARNING:root:Error valuating symbol "BTAI": could not convert string to float: '-'
# WARNING:root:No item with the key "BP-history" existed in the cache.
# WARNING:root:No item with the key "BYD-data" existed in the cache.
# WARNING:root:Error valuating symbol "BTCM": could not convert string to float: '-'
# WARNING:root:No item with the key "BHF-history" existed in the cache.
# WARNING:root:Error valuating symbol "BDTX": could not convert string to float: '-'
# WARNING:root:No item with the key "BMY-history" existed in the cache.
# WARNING:root:Error valuating symbol "BLNK": could not convert string to float: '-'
# WARNING:root:No item with the key "BRIOBUS-history" existed in the cache.
# WARNING:root:No item with the key "BP-data" existed in the cache.
# WARNING:root:No item with the key "BHF-data" existed in the cache.
# WARNING:root:No item with the key "BRIOBUS-data" existed in the cache.
# - BRIOBUS: No data found, symbol may be delisted
# WARNING:root:No item with the key "AVGO-history" existed in the cache.
# WARNING:root:No item with the key "BMY-data" existed in the cache.
# WARNING:root:No item with the key "AVGO-data" existed in the cache.
# ERROR:telegram.ext.updater:Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# ERROR:telegram.ext.dispatcher:No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/updater.py", line 651, in _network_loop_retry
#     if not action_cb():
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/updater.py", line 602, in polling_action_cb
#     updates = self.bot.get_updates(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/extbot.py", line 226, in get_updates
#     updates = super().get_updates(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 133, in decorator
#     result = func(*args, **kwargs)
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 3057, in get_updates
#     self._post(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 298, in _post
#     return self.request.post(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/utils/request.py", line 361, in post
#     result = self._request_wrapper(
# ...
# WARNING:root:Error valuating symbol "VOD": could not convert string to float: '-'
# WARNING:root:No item with the key "WAB-history" existed in the cache.
# WARNING:root:No item with the key "WPM-history" existed in the cache.
# WARNING:root:No item with the key "WB-data" existed in the cache.
# WARNING:root:No item with the key "WDC-data" existed in the cache.
# WARNING:root:No item with the key "WFC-data" existed in the cache.
# WARNING:root:No item with the key "WMB-history" existed in the cache.
# WARNING:root:No item with the key "WPM-data" existed in the cache.
# WARNING:root:No item with the key "WAB-data" existed in the cache.
# ERROR:telegram.ext.updater:Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# ERROR:telegram.ext.dispatcher:No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/updater.py", line 651, in _network_loop_retry
#     if not action_cb():
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/updater.py", line 602, in polling_action_cb
#     updates = self.bot.get_updates(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/extbot.py", line 226, in get_updates
#     updates = super().get_updates(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 133, in decorator
#     result = func(*args, **kwargs)
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 3057, in get_updates
#     self._post(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 298, in _post
#     return self.request.post(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/utils/request.py", line 361, in post
#     result = self._request_wrapper(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/utils/request.py", line 283, in _request_wrapper
#     raise Conflict(message)
# telegram.error.Conflict: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# WARNING:root:No item with the key "WIX-history" existed in the cache.
# WARNING:root:No item with the key "WMB-data" existed in the cache.
# WARNING:root:Error valuating symbol "WBD": could not convert string to float: '-'
# WARNING:root:No item with the key "WNS-history" existed in the cache.
# WARNING:root:No item with the key "WIX-data" existed in the cache.
# WARNING:root:No item with the key "WOLF-history" existed in the cache.
# WARNING:root:No item with the key "WNS-data" existed in the cache.
# WARNING:root:No item with the key "WDS-history" existed in the cache.
# WARNING:root:No item with the key "WOLF-data" existed in the cache.
# WARNING:root:No item with the key "WDS-data" existed in the cache.
# WARNING:root:No item with the key "WDAY-history" existed in the cache.
# WARNING:root:No item with the key "WDAY-data" existed in the cache.
# ERROR:telegram.ext.updater:Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# ERROR:telegram.ext.dispatcher:No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/updater.py", line 651, in _network_loop_retry
#     if not action_cb():
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/updater.py", line 602, in polling_action_cb
#     updates = self.bot.get_updates(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/extbot.py", line 226, in get_updates
#     updates = super().get_updates(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 133, in decorator
#     result = func(*args, **kwargs)
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 3057, in get_updates
#     self._post(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 298, in _post
#     return self.request.post(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/utils/request.py", line 361, in post
#     result = self._request_wrapper(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/utils/request.py", line 283, in _request_wrapper
#     raise Conflict(message)
# telegram.error.Conflict: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# WARNING:root:No item with the key "WKHS-history" existed in the cache.
# WARNING:root:No item with the key "WKHS-data" existed in the cache.
# WARNING:root:No item with the key "WWE-history" existed in the cache.
# WARNING:root:No item with the key "WRAP-history" existed in the cache.
# WARNING:root:No item with the key "WYNN-history" existed in the cache.
# WARNING:root:No item with the key "XNCR-history" existed in the cache.
# WARNING:root:No item with the key "XPEV-history" existed in the cache.
# WARNING:root:No item with the key "WRAP-data" existed in the cache.
# WARNING:root:No item with the key "WWE-data" existed in the cache.
# WARNING:root:No item with the key "WYNN-data" existed in the cache.
# WARNING:root:No item with the key "XPEV-data" existed in the cache.
# WARNING:root:No item with the key "XNCR-data" existed in the cache.
# WARNING:root:Error valuating symbol "WIX": could not convert string to float: '-'
# WARNING:root:No item with the key "XPO-history" existed in the cache.
# WARNING:root:No item with the key "YETI-history" existed in the cache.
# WARNING:root:No item with the key "YETI-data" existed in the cache.
# WARNING:root:No item with the key "XPO-data" existed in the cache.
# ERROR:telegram.ext.updater:Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# ERROR:telegram.ext.dispatcher:No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/updater.py", line 651, in _network_loop_retry
#     if not action_cb():
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/updater.py", line 602, in polling_action_cb
#     updates = self.bot.get_updates(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/extbot.py", line 226, in get_updates
#     updates = super().get_updates(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 133, in decorator
#     result = func(*args, **kwargs)
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 3057, in get_updates
#     self._post(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 298, in _post
#     return self.request.post(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/utils/request.py", line 361, in post
#     result = self._request_wrapper(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/utils/request.py", line 283, in _request_wrapper
#     raise Conflict(message)
# telegram.error.Conflict: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# WARNING:root:Error valuating symbol "WOLF": could not convert string to float: '-'
# WARNING:root:No item with the key "DAO-history" existed in the cache.
# WARNING:root:No item with the key "YUM-history" existed in the cache.
# WARNING:root:Error valuating symbol "WDS": could not convert string to float: '-'
# WARNING:root:No item with the key "ZBRA-history" existed in the cache.
# WARNING:root:No item with the key "DAO-data" existed in the cache.
# WARNING:root:No item with the key "ZBRA-data" existed in the cache.
# WARNING:root:No item with the key "YUM-data" existed in the cache.
# WARNING:root:Error valuating symbol "WDAY": could not convert string to float: '-'
# WARNING:root:No item with the key "ZEN-history" existed in the cache.
# WARNING:root:No item with the key "ZEN-data" existed in the cache.
# ERROR:telegram.ext.updater:Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# ERROR:telegram.ext.dispatcher:No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/updater.py", line 651, in _network_loop_retry
#     if not action_cb():
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/updater.py", line 602, in polling_action_cb
#     updates = self.bot.get_updates(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/extbot.py", line 226, in get_updates
#     updates = super().get_updates(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 133, in decorator
#     result = func(*args, **kwargs)
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 3057, in get_updates
#     self._post(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 298, in _post
#     return self.request.post(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/utils/request.py", line 361, in post
#     result = self._request_wrapper(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/utils/request.py", line 283, in _request_wrapper
#     raise Conflict(message)
# telegram.error.Conflict: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# WARNING:root:Error valuating symbol "WKHS": could not convert string to float: '-'
# WARNING:root:No item with the key "Z-history" existed in the cache.
# WARNING:root:No item with the key "Z-data" existed in the cache.
# WARNING:root:Error valuating symbol "XPEV": could not convert string to float: '-'
# WARNING:root:No item with the key "ZBH-history" existed in the cache.
# WARNING:root:Error valuating symbol "WRAP": could not convert string to float: '-'
# WARNING:root:No item with the key "ZIMV-history" existed in the cache.
# WARNING:root:Error valuating symbol "WYNN": could not convert string to float: '-'
# WARNING:root:No item with the key "ZTS-history" existed in the cache.
# WARNING:root:Error valuating symbol "XNCR": could not convert string to float: '-'
# WARNING:root:No item with the key "ZM-history" existed in the cache.
# WARNING:root:No item with the key "ZS-history" existed in the cache.
# WARNING:root:No item with the key "ZIMV-data" existed in the cache.
# WARNING:root:No item with the key "ZM-data" existed in the cache.
# WARNING:root:No item with the key "ZBH-data" existed in the cache.
# WARNING:root:No item with the key "ZS-data" existed in the cache.
# WARNING:root:No item with the key "ZTS-data" existed in the cache.
# WARNING:root:No item with the key "ZNGA-history" existed in the cache.
# WARNING:root:No item with the key "ZNGA-data" existed in the cache.
# - ZNGA: No data found, symbol may be delisted
# WARNING:root:Error valuating symbol "DAO": could not convert string to float: '-'
# ERROR:telegram.ext.updater:Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# ERROR:telegram.ext.dispatcher:No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/updater.py", line 651, in _network_loop_retry
#     if not action_cb():
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/updater.py", line 602, in polling_action_cb
#     updates = self.bot.get_updates(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/extbot.py", line 226, in get_updates
#     updates = super().get_updates(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 133, in decorator
#     result = func(*args, **kwargs)
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 3057, in get_updates
#     self._post(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 298, in _post
#     return self.request.post(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/utils/request.py", line 361, in post
#     result = self._request_wrapper(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/utils/request.py", line 283, in _request_wrapper
#     raise Conflict(message)
# telegram.error.Conflict: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# WARNING:root:Error valuating symbol "ZEN": could not convert string to float: '-'
# ERROR:telegram.ext.updater:Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# ERROR:telegram.ext.dispatcher:No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/updater.py", line 651, in _network_loop_retry
#     if not action_cb():
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/updater.py", line 602, in polling_action_cb
#     updates = self.bot.get_updates(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/ext/extbot.py", line 226, in get_updates
#     updates = super().get_updates(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 133, in decorator
#     result = func(*args, **kwargs)
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 3057, in get_updates
#     self._post(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/bot.py", line 298, in _post
#     return self.request.post(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/utils/request.py", line 361, in post
#     result = self._request_wrapper(
#   File "/Users/deanmartin/miniforge3/envs/tensorflow-apple-metal/lib/python3.9/site-packages/telegram/utils/request.py", line 283, in _request_wrapper
#     raise Conflict(message)
# telegram.error.Conflict: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# WARNING:root:Error valuating symbol "Z": could not convert string to float: '-'
# WARNING:root:Error valuating symbol "ZNGA": 'NoneType' object has no attribute 'loc'
# WARNING:root:Error valuating symbol "ZIMV": could not convert string to float: '-'
# WARNING:root:Error valuating symbol "ZS": could not convert string to float: '-'
